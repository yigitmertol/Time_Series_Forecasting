# %%
import yfinance as yf

snp500 = yf.Ticker("^GSPC")

# %%
# history = snp500.history(period="max")
history.to_csv('../../../Data/SPX/SnP500_index.csv')

# %%
history['Close'].plot()

# %%
msft = yf.Ticker("MSFT")
msft_hist = msft.history(period='max')

# %%
msft_hist.head(5)
# Out:
#                 Open      High       Low     Close      Volume  Dividends  \
# Date
# 1986-03-13  0.057158  0.065563  0.057158  0.062761  1031788800        0.0
# 1986-03-14  0.062761  0.066124  0.062761  0.065003   308160000        0.0
# 1986-03-17  0.065003  0.066684  0.065003  0.066124   133171200        0.0
# 1986-03-18  0.066124  0.066684  0.063882  0.064443    67766400        0.0
# 1986-03-19  0.064443  0.065003  0.062762  0.063322    47894400        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0

# %%
import ta

msft_hist = ta.add_all_ta_features(msft_hist, close='Close', high='High', low='Low',open='Open', volume='Volume')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (dip_mio[i]/trs[i])
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:174: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (din_mio[i]/trs[i])

# %%
msft_hist.tail(10)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2019-11-04  144.830002  145.000000  144.160004  144.550003  16912000
# 2019-11-05  144.970001  145.020004  143.910004  144.460007  18250200
# 2019-11-06  144.369995  144.520004  143.199997  144.059998  16575800
# 2019-11-07  143.839996  144.880005  143.770004  144.259995  17786700
# 2019-11-08  143.979996  145.990005  143.759995  145.960007  16732700
# 2019-11-11  145.339996  146.419998  144.729996  146.110001  14362600
# 2019-11-12  146.279999  147.570007  146.059998  147.070007  18641600
# 2019-11-13  146.740005  147.460007  146.279999  147.309998  16919200
# 2019-11-14  147.020004  148.410004  147.000000  148.059998  19729800
# 2019-11-15  148.929993  149.793198  148.270004  149.669998  10952721
#
#             Dividends  Stock Splits    volume_adi    volume_obv  volume_cmf  \
# Date
# 2019-11-04        0.0           0.0 -6.552536e+04  1.330423e+10   -0.072502
# ...

# %%
msft_hist.to_csv('../../../Data/SPX/msft_with_ta.csv')

# %%
aapl = yf.Ticker("AAPL")

# %%
aapl_hist = aapl.history(period='max')
aapl_hist.head()
# Out:
#                 Open      High       Low     Close     Volume  Dividends  \
# Date
# 1980-12-12  0.407747  0.409520  0.407747  0.407747  117258400        0.0
# 1980-12-15  0.388246  0.388246  0.386473  0.386473   43971200        0.0
# 1980-12-16  0.359881  0.359881  0.358108  0.358108   26432000        0.0
# 1980-12-17  0.366972  0.368745  0.366972  0.366972   21610400        0.0
# 1980-12-18  0.377609  0.379382  0.377609  0.377609   18362400        0.0
#
#             Stock Splits
# Date
# 1980-12-12           0.0
# 1980-12-15           0.0
# 1980-12-16           0.0
# 1980-12-17           0.0
# 1980-12-18           0.0

# %%
aapl_hist = ta.add_all_ta_features(aapl_hist, close='Close', high='High', low='Low',open='Open', volume='Volume')

aapl_hist.to_csv('../../../Data/SPX/aapl_with_ta.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (dip_mio[i]/trs[i])
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:174: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (din_mio[i]/trs[i])

# %% [markdown]
# #### Google Trends

# %%
from google_trends_scraper.google_trends_scraper import GoogleTrendsScraper
# Out:
# before path: ['', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python36.zip', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/lib-dynload', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/setuptools-41.0.0-py3.6.egg', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/extensions', '/Users/yigitmertolkayabasi/.ipython']
# ...

# %%
min([aapl_hist.index.min(), msft_hist.index.min(), history.index.min()])
# Out:
# Timestamp('1927-12-30 00:00:00')

# %%
max([aapl_hist.index.max(), msft_hist.index.max(), history.index.max()])
# Out:
# Timestamp('2019-11-15 00:00:00')

# %%
scraper = GoogleTrendsScraper('Apple', start_date='2009-11-15', end_date='2010-11-15')

# %%
gts = GoogleTrendsScraper("It Is Wednesday My Dude", "2018-03-01", "2018-03-14", seconds_delay=30)

results = gts.scrape()
# Out:
# /Users/yigitmertolkayabasi/Thesis_Workspace/Time_Series_Forecasting/Data_Collection/SPX
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-6-abb5c6162ff7> in <module>()
#       1 gts = GoogleTrendsScraper("It Is Wednesday My Dude", "2018-03-01", "2018-03-14", seconds_delay=30)
#       2
# ----> 3 results = gts.scrape()
#
# ~/Thesis_Workspace/Time_Series_Forecasting/Data_Collection/SPX/google_trends_scraper/google_trends_scraper.py in scrape(self)
#     188             return self.weekly_scrape()
#     189         else:
# --> 190             return self.total_scrape()
#
# ~/Thesis_Workspace/Time_Series_Forecasting/Data_Collection/SPX/google_trends_scraper/google_trends_scraper.py in total_scrape(self)
#     172     def total_scrape(self):
#     173         url = self.generate_url(self.start_date, self.end_date)
# ...

# %%
import numpy as np
log_returns = (history['Close']/history['Close'].shift()).apply(np.log).dropna()

# %%
import pandas as pd
import numpy as np

import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
import statsmodels.stats as sms

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def tsplot(y, lags=None, figsize=(10, 8), style='bmh'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (3, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        qq_ax = plt.subplot2grid(layout, (2, 0))
        pp_ax = plt.subplot2grid(layout, (2, 1))
        
        y.plot(ax=ts_ax)
        ts_ax.set_title('Time Series Analysis Plots')
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)
        sm.qqplot(y, line='s', ax=qq_ax)
        qq_ax.set_title('QQ Plot')        
        scs.probplot(y, sparams=(y.mean(), y.std()), plot=pp_ax)

        plt.tight_layout()
    return

# %%
tsplot((history['Close']/history['Close'].shift()).dropna().apply(np.log), lags=30)

# %%
# Fit ARIMA(p, d, q) model to SPX log returns
# pick best order and final model based on aic

best_aic = np.inf 
best_order = None
best_mdl = None

pq_rng = range(5) # [0,1,2,3]
d_rng = range(2) # [0,1]
for i in pq_rng:
    for d in d_rng:
        for j in pq_rng:
            try:
                tmp_mdl = smt.ARIMA(log_returns[:5000], 
                          order=(i,d,j)).fit(method='mle',
                          trend='nc')
                tmp_aic = tmp_mdl.aic
                if tmp_aic < best_aic:
                    best_aic = tmp_aic
                    best_order = (i, d, j)
                    best_mdl = tmp_mdl
            except: continue


print('aic: {:6.2f} | order: {}'.format(best_aic, best_order))

# ARIMA model resid plot
_ = tsplot(best_mdl.resid, lags=30)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
np.sqrt(np.mean((best_mdl.predict(start=1,end=log_returns[:5000].shape[0])-log_returns.dropna()[:5000].values)**2))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 0.023634259974266842

# %%
np.sqrt(np.mean((log_returns.mean()-log_returns.values)**2))/log_returns.std()
# Out:
# 0.9999410359974722

# %%
(best_mdl.predict(start=1,end=log_returns.shape[0])>0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8475    False
# 8476     True
# 8477    False
# 8478     True
# 8479     True
# Length: 8480, dtype: bool
