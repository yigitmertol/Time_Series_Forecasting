# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 30
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  # unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # derivatives

state0 = [1, -1, 1]
state0_ = [1, -1+1e-16, 1]
t = np.arange(0.0, 500.0, 0.01)

states = odeint(f, state0, t )[49000:] 
states_ = odeint(f, state0_, t )[49000:]
# states += np.random.random(states.shape)/1.2

fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2], color='red')
ax.plot(states_[:,0], states_[:,1], states_[:,2], color='blue')
plt.show()

# %%
b =2000
k=10000
plt.figure(figsize=(10,2))
plt.plot(range(k)[b:], states[b:k,0])

# %%
states[:,0]
# Out:
# array([ 1.        ,  0.98024817,  0.96098544, ..., 12.65437087,
#        12.6510223 , 12.64701137])

# %%
np.array(np.random.random(3))
# Out:
# array([0.36827895, 0.02183395, 0.3646487 ])
