# %%
import os
# files = os.listdir()

# %%
import pandas as pd


data_frames = {}

# %%
for csvname in os.listdir():
    if '.csv' not in csvname or 'dyn' not in csvname or 'None' not in csvname or '(' in csvname:
        continue
    print(csvname)
#     shocklevel = float(csvname.split('.csv')[0].split('syssta')[1])
    data_frames[csvname] = pd.read_csv(csvname)   
    data_frames[csvname]['loss'].plot()
# Out:
# Mackey_Glass_LSTM_W30_sysdynNone.csv
# Mackey_Glass_LSTM_big_W30_sysdynNone.csv
# Mackey_Glass_SimpleRNN_W30_sysdynNone.csv
# Mackey_Glass_SimpleRNN_big_W30_sysdynNone.csv
# Mackey_Glass_GRU_big_W30_sysdynNone.csv
# Mackey_Glass_GRU_W30_sysdynNone.csv

# %%
# import matplotlib.pyplot as plt
# def plot_losses(System, Shock_level, rnn_type, rnn_size, data_frames):
    
#     plt.figure(figsize=(10,10))
#     for dfname , df in dataframes.items():
#         plt.plot(data_frames['Mackey_Glass_GRU_W30_sysstaNone.csv']['val_loss'], '--', color='r')
#     plt.plot(data_frames['Mackey_Glass_GRU_big_W30_sysstaNone.csv']['val_loss'],color='r')
#     plt.plot(data_frames['Mackey_Glass_LSTM_W30_sysstaNone.csv']['val_loss'],  '--', color='b')
#     plt.plot(data_frames['Mackey_Glass_LSTM_big_W30_sysstaNone.csv']['val_loss'],color='b')
#     plt.plot(data_frames['Mackey_Glass_SimpleRNN_W30_sysstaNone.csv']['val_loss'], '--' ,color='purple')
#     plt.plot(data_frames['Mackey_Glass_SimpleRNN_big_W30_sysstaNone.csv']['val_loss'], color='purple')
