# %%
# External packages
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import datetime 


# Internal packages
import sys
sys.path.append('../../Time_Series_Forecasting/TS_helpers/')
sys.path.append('../../Time_Series_Forecasting/')
sys.path.append('../DeepESN-master/DeepESN/')
from dates_kaggle1min import make_all_time_indexes, make_integer_time_index

# %%
data = pd.read_csv('../../Data/Coins/BTC_USD/Trade_Data/BITSTAMP_TRADE_SPOTBTC_cum_.csv', index_col='uuid')
print(data.shape)
# data.tail()
# Out:
# (6864988, 19)

# %%
# Out:
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# 201711
# ...

# %%
# same =True
for i in range(4):
    data.iloc[i, :]
#     print(set(data.iloc[i, :].values).difference(set(data_broken_fixed.iloc[i,:].values)))

# %%
data_fixed_all.iloc[:4, :]
# Out:
#                                             date  day  hour  minute  month  \
# uuid
# 631ab21d-7be4-4748-8a1c-f605634458c7  2017-11-10   10    16      36     11
# 1e757fb5-fe9e-4aa8-9b23-65bcc5b9f151  2017-11-10   10    16      36     11
# 99676024-9c9a-4e4a-8d55-3cd65e39dffa  2017-11-10   10    16      36     11
# 01683e56-e26b-4cf6-a6ae-6e642b0eb385  2017-11-10   10    16      36     11
#
#                                         price  second                 size  \
# uuid
# 631ab21d-7be4-4748-8a1c-f605634458c7  6945.36       5           0.06606568
# 1e757fb5-fe9e-4aa8-9b23-65bcc5b9f151  6935.21       8             0.144313
# 99676024-9c9a-4e4a-8d55-3cd65e39dffa  6945.37      12           0.34963156
# 01683e56-e26b-4cf6-a6ae-6e642b0eb385  6945.37      16  0.16837827000000002
#
#                                                   symbol_id taker_side  \
# uuid
# 631ab21d-7be4-4748-8a1c-f605634458c7  BITSTAMP_SPOT_BTC_USD        BUY
# ...

# %%
len(set(data_correct.index).intersection(set(data_fixed_all.index)))
# Out:
# 6464988

# %%
data.shape[0]-data_broken.shape[0]
# Out:
# 6464988

# %%
data_fixed_all.to_csv('../../Data/Coins/BTC_USD/Trade_Data/BITSTAMP_TRADE_SPOTBTC_cum_.csv')
